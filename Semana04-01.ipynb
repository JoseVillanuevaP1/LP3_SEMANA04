# %% [markdown]
# # SEMANA 04
# Jose Moises Villanueva Parrera

# %% [raw]
# Agenda
#
# 1. Numeros
# 2. Variables
# 3. Manejo de cadenas
# 4. Ingreso por el teclado
# 5. Operadores

# %% [raw]
# 1. Numeros

# %%
7+9
# Out:
# 16

# %%
36-25
# Out:
# 11

# %%
35*8
# Out:
# 280

# %%
72/9
# Out:
# 8.0
