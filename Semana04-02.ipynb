# %% [raw]
# #SEMANA 04
# Jose Moises Villanueva Parrera

# %% [raw]
# Agenda
#
#
# 1. Numeros
# 2. Variables
# 3. Manejo de cadenas
# 4. Ingreso por el teclado
# 5. Operadores

# %% [raw]
# 2. Variables

# %%
#Se debe iniciar siempre con una letra o un guion abajo. (Nunca con un numero u otro simbolo)

# %%
edad = 21

# %%
edad
# Out:
# 21

# %%
nombre = "Jose"

# %%
nombre
# Out:
# 'Jose'

# %%
apellido = "Villanueva Parrera"

# %%
apellido
# Out:
# 'Villanueva Parrera'

# %%
nombrecompleto = nombre + " " + apellido

# %%
nombrecompleto
# Out:
# 'Jose Villanueva Parrera'

# %%
#Para saber el tipo de variable utlizamos la funcion type
#Por ejemplo
numero =  50
type(numero)
# Out:
# int

# %%
talla = 1.66

# %%
talla
# Out:
# 1.66

# %%
type(talla)
# Out:
# float

# %%
numero = 100
cadena  = str(numero)
cadena
# Out:
# '100'

# %%
#Para convertir una cadena a un entero utilixamos float()
cadena2 = "50"
numero2 = int(cadena2)
numero2
# Out:
# 50

# %%
type(numero2)
# Out:
# int

# %%
#Para convertir una cadena a un decimal utilixamos float()
cadena2 = "50"
numero2 = float(cadena2)
numero2
# Out:
# 50.0
